# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://storage.googleapis.com/datasets-academy/public-img/notebooks/headers/databits-header-notebook.png" alt="Databricks Learning" style="width: 100%;">
# </div>
#
# # <center>  Ejercicio práctico: Introducción a Python </center>
#
# ## Descripción
# Este ejercicio busca profundizar en el uso de Python y Pandas para la manipulación de DataFrames. Además, fortalecer la creación de visualizaciones mediante el uso de Databricks.
#
# <img alt="Caution" title="Caution" style="vertical-align: text-bottom; position: relative; height:1.3em; top:0.0em" src="https://storage.googleapis.com/datasets-academy/public-img/notebooks/icons/danger.png"/> **Disclaimer:** Este material ha sido preparado por el equipo de **handytec Academy®**. Se prohibe la publicación o reproducción de este material sin previa autorización de **handytec Academy®** - 2022 Todos los derechos reservados.

# %% [markdown]
# ##### Importante antes de comenzar vamos a necesitar instalar siguiente versión de la librería xlrd en nuestro cluster activo, proceda a instalarla:
#
# `xlrd==1.2.0`

# %%
# Ejecutar esta línea de código
! pip install xlrd==1.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 103 kB 5.2 MB/s
# ...
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 1.1.0
#     Uninstalling xlrd-1.1.0:
#       Successfully uninstalled xlrd-1.1.0
# ...

# %% [markdown]
# Para confirmar que el clúster se actualice con la nueva librería, hacer clic en el desplegable donde se vincula (attached) nuestro notebook y el clúster. Dar clic en la opción **`Detach and Re-attach`** y confirmar el proceso

# %% [markdown]
# #### 1. Importa los módulos NumPy y Pandas para trabajar durante el notebook. Y verifica las versiones de los mismos.

# %%
# Coloca tu código aquí
import numpy as np
import pandas as pd

# %% [markdown]
# A continuación, se va a leer un dataset correspondiente a las ventas realizadas por una empresa para el año 2018 (archivo Excel)
#
# **Diccionario de datos**
#
# `account number`: Cuenta bancaria del cliente (**tipo de dato: alfanumérico**) <br>
# `name`: Nombre del cliente (**tipo de dato: alfanumérico**) <br>
# `sku`: Codigo identificador del producto propio de la empresa (**tipo de dato: alfanumérico**) <br>
# `quantity`: Cantidad del producto (**tipo de dato: numérico**) <br>
# `unit price`: Precio Unitario del producto (**tipo de dato: numérico**)<br>
# `ext price`: Ventas totales, cantidad multiplicada por el precio (**tipo de dato: numérico**)<br>
# `date`: Fecha de compra (**tipo de dato: fecha**)
# <br>

# %%
# Lectura archivo excel
url = 'https://github.com/chris1610/pbpython/raw/master/data/2018_Sales_Total_Tabs.xlsx'
df = pd.read_excel(url, sheet_name='Sheet1')
df
# Out:
#     account number                             name       sku  quantity  \
# 0           412290                    Jerde-Hilpert  S2-77896        43
# 1           383080                         Will LLC  S1-93683        28
# 2           729833                        Koepp Ltd  S1-30248        13
# 3           424914                    White-Trantow  S2-82423        38
# 4           672390                  Kuhn-Gusikowski  S1-50961        34
# 5           239344                       Stokes LLC  S2-10342        34
# 6           218895                        Kulas Inc  S2-34077        30
# 7           672390                  Kuhn-Gusikowski  B1-05914        25
# 8           740150                       Barton LLC  S1-82801        29
# 9           218895                        Kulas Inc  B1-20000        23
# 10          257198  Cronin, Oberbrunner and Spencer  S1-30248        14
# 11          672390                  Kuhn-Gusikowski  S2-83881        26
# ...

# %% [markdown]
# #### 2. Desplegar las 5 primeras filas de nuestro dataframe

# %%
# Coloca tu código aquí
df[0:5]
# Out:
#    account number             name       sku  quantity  unit price  ext price  \
# 0          412290    Jerde-Hilpert  S2-77896        43       76.66    3296.38
# 1          383080         Will LLC  S1-93683        28       90.86    2544.08
# 2          729833        Koepp Ltd  S1-30248        13       44.84     582.92
# 3          424914    White-Trantow  S2-82423        38       50.93    1935.34
# 4          672390  Kuhn-Gusikowski  S1-50961        34       48.20    1638.80
#
#                  date
# 0 2018-03-04 23:10:28
# 1 2018-03-05 05:11:49
# 2 2018-03-05 17:33:52
# 3 2018-03-05 21:40:10
# 4 2018-03-06 11:59:00

# %%
df.head()
# Out:
#    account number             name       sku  quantity  unit price  ext price  \
# 0          412290    Jerde-Hilpert  S2-77896        43       76.66    3296.38
# 1          383080         Will LLC  S1-93683        28       90.86    2544.08
# 2          729833        Koepp Ltd  S1-30248        13       44.84     582.92
# 3          424914    White-Trantow  S2-82423        38       50.93    1935.34
# 4          672390  Kuhn-Gusikowski  S1-50961        34       48.20    1638.80
#
#                  date
# 0 2018-03-04 23:10:28
# 1 2018-03-05 05:11:49
# 2 2018-03-05 17:33:52
# 3 2018-03-05 21:40:10
# 4 2018-03-06 11:59:00

# %% [markdown]
# #### 3. Realizar un conteo del número de filas y columnas

# %%
# Coloca tu código aquí
print(df.shape)
print('Número de filas:', df.shape[0])
print('Número de columnas:', df.shape[1])
# Out:
# (39, 7)
# Número de filas: 39
# Número de columnas: 7

# %% [markdown]
# #### 4. Imprimir el tipo de datos de las columnas del dataframe

# %%
# Coloca tu código aquí
print(df.dtypes)
# Out:
# account number             int64
# name                      object
# sku                       object
# quantity                   int64
# unit price               float64
# ext price                float64
# date              datetime64[ns]
# dtype: object

# %% [markdown]
# #### 5. Transformar la columna **account number** a tipo cadena de caracteres (object). Y confirmar la transformación en el tipo de dato.

# %%
# Coloca tu código aquí (Pista: usar el método astype)
df['account number'] = df['account number'].astype(object)
print('Tipo de dato account number:', df['account number'].dtypes)
print(df.dtypes)
# Out:
# Tipo de dato account number: object
# account number            object
# name                      object
# sku                       object
# quantity                   int64
# unit price               float64
# ext price                float64
# date              datetime64[ns]
# dtype: object

# %% [markdown]
# #### 6. Crear un nuevo DataFrame llamado `df_seleccion`, seleccionando unicamente las columnas: `sku`, `quantity`, `unit price`, `ext price`, `date`

# %%
# Coloca tu código aquí
'''Andres Teran <
Carlos Calderon <
Diego Tipan
Erick Ns'''

# %%
df_seleccion = df[['sku','quantity','unit price','ext price','date']].copy()
df_seleccion.head()
# Out:
#         sku  quantity  unit price  ext price                date
# 0  S2-77896        43       76.66    3296.38 2018-03-04 23:10:28
# 1  S1-93683        28       90.86    2544.08 2018-03-05 05:11:49
# 2  S1-30248        13       44.84     582.92 2018-03-05 17:33:52
# 3  S2-82423        38       50.93    1935.34 2018-03-05 21:40:10
# 4  S1-50961        34       48.20    1638.80 2018-03-06 11:59:00

# %% [markdown]
# #### 7. Renombrar las columnas del dataframe `df_seleccion` según lo que se indica a continuación:
# `sku`: codigo
# `quantity`: cantidad
# `unit price`: precio_unitario
# `ext price`: venta_total
# `date`: fecha
#
# Por último, imprima el nombre de las columnas para verificar el cambio realizado

# %%
# Coloca tu código aquí
Estefania Cisneros
Fabian Ortiz
Fernando Salas
Liliana Acosta

# %%
dic_rp = {'sku':'codigo',
          'quantity':'cantidad',
          'unit price': 'precio_unitario',
          'ext price': 'venta_total',
          'date':'fecha'}
print(df_seleccion.keys())
df_seleccion = df_seleccion.rename(columns=dic_rp,inplace=False)
df_seleccion.keys()
# Out:
# Index(['codigo', 'cantidad', 'precio_unitario', 'venta_total', 'fecha'], dtype='object')
# Index(['codigo', 'cantidad', 'precio_unitario', 'venta_total', 'fecha'], dtype='object')

# %% [markdown]
# #### 8. Crear un nuevo DataFrame llamado `df_filtrado`, donde conservemos aquellos clientes que generaron una venta total mayor a 55 dólares a partir del dataframe `df_seleccion`

# %%
# Coloca tu código aquí
María José Puente
Norma Amaguaña
Robert

# %%
# Ejercicio 8
df_filtrado = df_seleccion[df_seleccion['precio_unitario'] >55]
df_filtrado.describe()
# Out:
#         cantidad  precio_unitario  venta_total
# count  24.000000        24.000000    24.000000
# mean   21.750000        82.068333  1785.719583
# std    13.122334        13.941630  1081.999203
# min     1.000000        58.040000    96.070000
# 25%    12.750000        70.677500   965.772500
# 50%    24.000000        87.890000  1927.530000
# 75%    29.250000        93.842500  2567.290000
# max    44.000000        99.730000  3758.200000

# %% [markdown]
# #### 9. Del dataframe`df_filtrado` identificar los códigos de los productos con una mayor frecuencia de venta (`cantidad`).
#
# Para ello, en el dataframe`df_filtrado` aplicar un agrupamiento por código de producto `codigo`, empleando como método de agregación la sumatoria (`sum`) y finalmente ordenar el dataframe de forma descendente de acuerdo a la columna `cantidad`

# %%
# Coloca tu código aquí
Ruth
Wilson
Janeth

# %%
df_agrupado = df_filtrado.groupby('codigo').agg({'cantidad':'sum', 'precio_unitario':'mean', 'venta_total':'sum'}).sort_values(by='venta_total', ascending=False)
df_agrupado
# Out:
#           cantidad  precio_unitario  venta_total
# codigo
# S1-82801        93        76.957500      7270.16
# S1-93683        67        88.610000      5726.46
# S2-77896        71        81.163333      5302.97
# S2-23246        43        87.400000      3758.20
# B1-05914        40        77.680000      3229.00
# S2-34077        30        99.730000      2991.90
# B1-53636        44        59.930000      2636.92
# S2-83881        26        88.380000      2297.88
# B1-20000        23        99.570000      2290.11
# S2-10342        25        82.035000      2039.27
# S1-47412        21        94.450000      1983.45
# B1-33364        17        93.010000      1581.17
# S1-30248        14        91.370000      1279.18
# B1-65551         6        58.040000       348.24
# B1-38851         2        61.180000       122.36

# %%
df_agrupado = df_filtrado.groupby('codigo').sum().sort_values(by='venta_total', ascending=False)
df_agrupado
# Out:
#           cantidad  precio_unitario  venta_total
# codigo
# S1-82801        93           307.83      7270.16
# S1-93683        67           265.83      5726.46
# S2-77896        71           243.49      5302.97
# S2-23246        43            87.40      3758.20
# B1-05914        40           155.36      3229.00
# S2-34077        30            99.73      2991.90
# B1-53636        44            59.93      2636.92
# S2-83881        26            88.38      2297.88
# B1-20000        23            99.57      2290.11
# S2-10342        25           164.07      2039.27
# S1-47412        21            94.45      1983.45
# B1-33364        17            93.01      1581.17
# S1-30248        14            91.37      1279.18
# B1-65551         6            58.04       348.24
# B1-38851         2            61.18       122.36

# %% [markdown]
# #### 10. Tabla interactiva del DataFrame `df_filtrado`
#
# Analizar las funcionalidades disponibles en la tabla interactiva

# %%
# Activar el botón en la esquina superior derecha para ver el DataFrame en forma de tabla interactiva
df_filtrado

# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://storage.googleapis.com/datasets-academy/public-img/notebooks/headers/databits-footer-notebook.png" alt="Databricks Learning" style="width: 100%;">
# </div>
